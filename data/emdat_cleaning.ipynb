# %%
import pandas as pd

# %%
path_emdat=('/Users/tatiana/Documents/disaster_response/emdat.csv')

# %%
#emdat data for all natural disasters from 1900-2021
df_emdat=pd.read_csv(path_emdat,sep=',')

# %%
df_emdat.head()
# Out:
#           Dis No  Year  Month   Day      Disaster Type Disaster Subtype  \
# 0  1900-9002-CPV  1900    NaN   NaN            Drought          Drought
# 1  1900-9001-IND  1900    NaN   NaN            Drought          Drought
# 2  1902-0012-GTM  1902    4.0  18.0         Earthquake  Ground movement
# 3  1902-0003-GTM  1902    4.0   8.0  Volcanic activity         Ash fall
# 4  1902-0010-GTM  1902   10.0  24.0  Volcanic activity         Ash fall
#
#       Country Country Code           Region Continent  ... No Affected  \
# 0  Cabo Verde          CPV   Western Africa    Africa  ...         NaN
# 1       India          IND    Southern Asia      Asia  ...         NaN
# 2   Guatemala          GTM  Central America  Americas  ...         NaN
# 3   Guatemala          GTM  Central America  Americas  ...         NaN
# 4   Guatemala          GTM  Central America  Americas  ...         NaN
#
#   No Homeless Total Affected Reconstruction Costs ('000 US$)  \
# ...

# %%
#emdat data summary for all natural disasters
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16234 entries, 0 to 16233
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Dis No                                     16234 non-null  object
#  1   Year                                       16234 non-null  int64
#  2   Month                                      15846 non-null  float64
#  3   Day                                        12603 non-null  float64
#  4   Disaster Type                              16234 non-null  object
#  5   Disaster Subtype                           13077 non-null  object
#  6   Country                                    16234 non-null  object
#  7   Country Code                               16234 non-null  object
#  8   Region                                     16234 non-null  object
#  9   Continent                                  16234 non-null  object
# ...

# %%
#extracting data with Disaster Type earthquake only
df_earthquake=df_emdat[df_emdat["Disaster Type"] == "Earthquake"]

# %%
#reseting index to re-index numbering starting from 0
df_earthquake=df_earthquake.reset_index()

# %%
df_earthquake=df_earthquake.drop(columns=['index'])

# %%
df_earthquake.columns
# Out:
# Index(['Dis No', 'Year', 'Month', 'Day', 'Disaster Type', 'Disaster Subtype',
#        'Country', 'Country Code', 'Region', 'Continent', 'Location',
#        'Associated Dis', 'Associated Dis2', 'OFDA Response', 'Appeal',
#        'Declaration', 'Aid Contribution', 'Dis Mag Value', 'Latitude',
#        'Longitude', 'Local Time', 'Total Deaths', 'No Injured', 'No Affected',
#        'No Homeless', 'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damages ('000 US$)', 'Insured Damages, Adjusted ('000 US$)',
#        'Total Damages ('000 US$)', 'Total Damages, Adjusted ('000 US$)',
#        'CPI'],
#       dtype='object')

# %%
df_earthquake.head()
# Out:
#           Dis No  Year  Month   Day Disaster Type Disaster Subtype    Country  \
# 0  1902-0012-GTM  1902    4.0  18.0    Earthquake  Ground movement  Guatemala
# 1  1905-0003-IND  1905    4.0   4.0    Earthquake  Ground movement      India
# 2  1906-0014-CHL  1906    8.0  16.0    Earthquake  Ground movement      Chile
# 3  1906-0002-COL  1906    1.0  31.0    Earthquake  Ground movement   Colombia
# 4  1907-0006-CHN  1907   10.0  21.0    Earthquake  Ground movement      China
#
#   Country Code           Region Continent  ... No Affected No Homeless  \
# 0          GTM  Central America  Americas  ...         NaN         NaN
# 1          IND    Southern Asia      Asia  ...         NaN         NaN
# 2          CHL    South America  Americas  ...         NaN         NaN
# 3          COL    South America  Americas  ...         NaN         NaN
# 4          CHN     Eastern Asia      Asia  ...         NaN         NaN
#
#   Total Affected Reconstruction Costs ('000 US$)  \
# ...

# %%
#summary of data for earthquakes 
df_earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1554 entries, 0 to 1553
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Dis No                                     1554 non-null   object
#  1   Year                                       1554 non-null   int64
#  2   Month                                      1552 non-null   float64
#  3   Day                                        1551 non-null   float64
#  4   Disaster Type                              1554 non-null   object
#  5   Disaster Subtype                           1551 non-null   object
#  6   Country                                    1554 non-null   object
#  7   Country Code                               1554 non-null   object
#  8   Region                                     1554 non-null   object
#  9   Continent                                  1554 non-null   object
# ...

# %%
#Data from USGS on earthquakes magnitude, depth and longitude/latitude from 1900-1910 for magnitude greater than 5
#includes ALL possible earthquakes over the given period in the world, ocean and land
path_usgs=('/Users/tatiana/Documents/disaster_response/1950_60.csv')

# %%
usgs_data=pd.read_csv(path_usgs,',')

# %% [markdown]
# year month date columns - convert into datetime from emdat data
# filter out data set 1960+ from emdat
# merge usgs csvs 1960+

# %%
usgs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2897 entries, 0 to 2896
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             2897 non-null   object
#  1   latitude         2897 non-null   float64
#  2   longitude        2897 non-null   float64
#  3   depth            2800 non-null   float64
#  4   mag              2897 non-null   float64
#  5   magType          2897 non-null   object
#  6   nst              65 non-null     float64
#  7   gap              65 non-null     float64
#  8   dmin             29 non-null     float64
#  9   rms              65 non-null     float64
#  10  net              2897 non-null   object
#  11  id               2897 non-null   object
#  12  updated          2897 non-null   object
#  13  place            2897 non-null   object
#  14  type             2897 non-null   object
#  15  horizontalError  63 non-null     float64
# ...

# %%
usgs_data.iloc[25:35]
# Out:
#                         time  latitude  longitude  depth  mag magType  nst  \
# 25  1950-03-03T15:41:12.000Z   -60.426    -34.821   15.0  5.8      mw  NaN
# 26  1950-03-04T15:48:35.000Z   -59.820    -28.658   15.0  5.9      mw  NaN
# 27  1950-03-07T02:07:53.000Z    10.600    122.467   25.0  6.7      mw  NaN
# 28  1950-03-09T10:03:42.000Z    15.760    -60.544   15.0  5.7      mw  NaN
# 29  1950-03-18T04:39:37.000Z   -57.427    -23.658   15.0  6.4      mw  NaN
# 30  1950-03-20T15:22:17.000Z    40.450   -121.467    NaN  5.5      ml  NaN
# 31  1950-03-26T16:53:28.000Z    14.485     39.628   15.0  5.6      mw  NaN
# 32  1950-03-27T13:04:08.000Z    53.380    172.220   25.0  6.4      mw  NaN
# 33  1950-03-27T21:18:36.000Z    -5.729    103.083   35.0  6.4      mw  NaN
# 34  1950-04-04T03:42:51.000Z    29.454    130.445   55.0  6.0      mw  NaN
#
#     gap  dmin  rms  ...                   updated  \
# 25  NaN   NaN  NaN  ...  2015-05-13T18:52:45.000Z
# ...

# %%
df_earthquake.columns
# Out:
# Index(['Dis No', 'Year', 'Month', 'Day', 'Disaster Type', 'Disaster Subtype',
#        'Country', 'Country Code', 'Region', 'Continent', 'Location',
#        'Associated Dis', 'Associated Dis2', 'OFDA Response', 'Appeal',
#        'Declaration', 'Aid Contribution', 'Dis Mag Value', 'Latitude',
#        'Longitude', 'Local Time', 'Total Deaths', 'No Injured', 'No Affected',
#        'No Homeless', 'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damages ('000 US$)', 'Insured Damages, Adjusted ('000 US$)',
#        'Total Damages ('000 US$)', 'Total Damages, Adjusted ('000 US$)',
#        'CPI'],
#       dtype='object')

# %%
df_earthquake[['Year', 'Month', 'Day','Country','Dis Mag Value', 'Latitude','Longitude',]]
# Out:
#       Year  Month   Day     Country  Dis Mag Value Latitude Longitude
# 0     1902    4.0  18.0   Guatemala            8.0       14       -91
# 1     1905    4.0   4.0       India            8.0    32.04     76.16
# 2     1906    8.0  16.0       Chile            8.0    33.05      71.4
# 3     1906    1.0  31.0    Colombia            9.0   1.51 N  78.46 W
# 4     1907   10.0  21.0       China            7.0     38.5      69.9
# ...    ...    ...   ...         ...            ...      ...       ...
# 1549  2020    2.0  23.0      Turkey            6.0   38.543    44.447
# 1550  2020    6.0  14.0      Turkey            6.0   39.421    40.697
# 1551  2020    6.0  25.0      Turkey            5.0   38.558    44.023
# 1552  2020   10.0  30.0      Turkey            7.0   37.913    26.779
# 1553  2021    7.0  10.0  Tajikistan            6.0      NaN       NaN
#
# [1554 rows x 7 columns]

# %%
path_naturaldisasters=('/Users/tatiana/Documents/disaster_response/natural-disasters.csv')

# %%
df_natdisasters=pd.read_csv(path_naturaldisasters,',')

# %%
for col_name in df_natdisasters.columns: 
    print(col_name)
# Out:
# Number of deaths from drought
# Number of people injured from drought
# Number of people affected from drought
# Number of people left homeless from drought
# Number of total people affected by drought
# Reconstruction costs from drought
# Insured damages against drought
# Total economic damages from drought
# Death rates from drought
# Injury rates from drought
# Number of people affected by drought per 100,000
# Homelessness rate from drought
# Total number of people affected by drought per 100,000
# Number of deaths from earthquakes
# Number of people injured from earthquakes
# Number of people affected by earthquakes
# Number of people left homeless from earthquakes
# Number of total people affected by earthquakes
# Reconstruction costs from earthquakes
# Insured damages against earthquakes
# Total economic damages from earthquakes
# Death rates from earthquakes
# Injury rates from earthquakes
# Number of people affected by earthquakes per 100,000
# ...

# %%
import geopandas as geopd
