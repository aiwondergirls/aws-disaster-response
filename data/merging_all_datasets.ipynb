# %%
import pandas as pd 
import datetime
from shapely.geometry import Point, shape, Polygon
import geopandas as gpd
import shapely.speedups
from pprint import pprint

# %% [markdown]
# # US-GS dataset
#
# We use the [US-GS dataset](https://www.usgs.gov/programs/earthquake-hazards/earthquakes) to acquire overall information about earthquakes. In order to determine a country for this dataset, which only contains coordinates of events, we merge it to the [Natural Earth dataset](https://www.naturalearthdata.com/downloads/10m-cultural-vectors/) which contains country codes and polygons for each country. The data only contains earthquakes registered past 1959, in order to match the dates of the other datasets used in this project.

# %%
# Dataset with countries geometry and code

countries_df = gpd.read_file("ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")

# %%
countries_df=countries_df.rename(columns={'SOV_A3':'country code'})

# %%
countries_df.head()
# Out:
#         featurecla  scalerank  LABELRANK SOVEREIGNT country code  ADM0_DIF  \
# 0  Admin-0 country          0          2  Indonesia          IDN         0
# 1  Admin-0 country          0          3   Malaysia          MYS         0
# 2  Admin-0 country          0          2      Chile          CHL         0
# 3  Admin-0 country          0          3    Bolivia          BOL         0
# 4  Admin-0 country          0          2       Peru          PER         0
#
#    LEVEL               TYPE      ADMIN ADM0_A3  ...  FCLASS_TR FCLASS_ID  \
# 0      2  Sovereign country  Indonesia     IDN  ...       None      None
# 1      2  Sovereign country   Malaysia     MYS  ...       None      None
# 2      2  Sovereign country      Chile     CHL  ...       None      None
# 3      2  Sovereign country    Bolivia     BOL  ...       None      None
# 4      2  Sovereign country       Peru     PER  ...       None      None
#
#   FCLASS_PL  FCLASS_GR FCLASS_IT FCLASS_NL  FCLASS_SE FCLASS_BD FCLASS_UA  \
# 0      None       None      None      None       None      None      None
# 1      None       None      None      None       None      None      None
# 2      None       None      None      None       None      None      None
# 3      None       None      None      None       None      None      None
# 4      None       None      None      None       None      None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  MULTIPOLYGON (((-69.51009 -17.50659, -69.50611...
# 3  POLYGON ((-69.51009 -17.50659, -69.51009 -17.5...
# 4  MULTIPOLYGON (((-69.51009 -17.50659, -69.63832...
#
# [5 rows x 162 columns]

# %%
countries_df=countries_df.replace({'country code':'CH1'}, 'CHN')

# %%
countries_df=countries_df.replace({'country code':'US1'}, 'USA')
countries_df=countries_df.replace({'country code':'GB1'}, 'GBR')
countries_df=countries_df.replace({'country code':'CU1'}, 'CUB')
countries_df=countries_df.replace({'country code':'FR1'}, 'FRA')
countries_df=countries_df.replace({'country code':'KA1'}, 'KAZ')
countries_df=countries_df.replace({'country code':'AU1'}, 'AUS')
countries_df=countries_df.replace({'country code':'NZ1'}, 'NZL')

# %%
countries_df[['country code','SOVEREIGNT']].values
# Out:
# array([['IDN', 'Indonesia'],
#        ['MYS', 'Malaysia'],
#        ['CHL', 'Chile'],
#        ['BOL', 'Bolivia'],
#        ['PER', 'Peru'],
#        ['ARG', 'Argentina'],
#        ['GBR', 'United Kingdom'],
#        ['CYP', 'Cyprus'],
#        ['IND', 'India'],
#        ['CHN', 'China'],
#        ['IS1', 'Israel'],
#        ['IS1', 'Israel'],
#        ['LBN', 'Lebanon'],
#        ['ETH', 'Ethiopia'],
#        ['SDS', 'South Sudan'],
#        ['SOM', 'Somalia'],
#        ['KEN', 'Kenya'],
#        ['MWI', 'Malawi'],
#        ['TZA', 'United Republic of Tanzania'],
#        ['SYR', 'Syria'],
#        ['SOL', 'Somaliland'],
#        ['FRA', 'France'],
#        ['SUR', 'Suriname'],
#        ['GUY', 'Guyana'],
#        ['KOR', 'South Korea'],
#        ['PRK', 'North Korea'],
#        ['MAR', 'Morocco'],
#        ['SAH', 'Western Sahara'],
#        ['CRI', 'Costa Rica'],
#        ['NIC', 'Nicaragua'],
#        ['COG', 'Republic of the Congo'],
#        ['COD', 'Democratic Republic of the Congo'],
#        ['BTN', 'Bhutan'],
#        ['UKR', 'Ukraine'],
#        ['BLR', 'Belarus'],
#        ['NAM', 'Namibia'],
#        ['ZAF', 'South Africa'],
#        ['FRA', 'France'],
#        ['NL1', 'Netherlands'],
#        ['OMN', 'Oman'],
#        ['UZB', 'Uzbekistan'],
#        ['KAZ', 'Kazakhstan'],
#        ['TJK', 'Tajikistan'],
#        ['LTU', 'Lithuania'],
#        ['BRA', 'Brazil'],
#        ['URY', 'Uruguay'],
#        ['MNG', 'Mongolia'],
#        ['RUS', 'Russia'],
#        ['CZE', 'Czechia'],
#        ['DEU', 'Germany'],
#        ['EST', 'Estonia'],
#        ['LVA', 'Latvia'],
#        ['NOR', 'Norway'],
#        ['SWE', 'Sweden'],
#        ['FI1', 'Finland'],
#        ['VNM', 'Vietnam'],
#        ['KHM', 'Cambodia'],
#        ['LUX', 'Luxembourg'],
#        ['ARE', 'United Arab Emirates'],
#        ['BEL', 'Belgium'],
#        ['GEO', 'Georgia'],
#        ['MKD', 'North Macedonia'],
#        ['ALB', 'Albania'],
#        ['AZE', 'Azerbaijan'],
#        ['KOS', 'Kosovo'],
#        ['TUR', 'Turkey'],
#        ['ESP', 'Spain'],
#        ['LAO', 'Laos'],
#        ['KGZ', 'Kyrgyzstan'],
#        ['ARM', 'Armenia'],
#        ['DN1', 'Denmark'],
#        ['LBY', 'Libya'],
#        ['TUN', 'Tunisia'],
#        ['ROU', 'Romania'],
#        ['HUN', 'Hungary'],
#        ['SVK', 'Slovakia'],
#        ['POL', 'Poland'],
#        ['IRL', 'Ireland'],
#        ['GBR', 'United Kingdom'],
#        ['GRC', 'Greece'],
#        ['ZMB', 'Zambia'],
#        ['SLE', 'Sierra Leone'],
#        ['GIN', 'Guinea'],
#        ['LBR', 'Liberia'],
#        ['CAF', 'Central African Republic'],
#        ['SDN', 'Sudan'],
#        ['DJI', 'Djibouti'],
#        ['ERI', 'Eritrea'],
#        ['AUT', 'Austria'],
#        ['IRQ', 'Iraq'],
#        ['ITA', 'Italy'],
#        ['CHE', 'Switzerland'],
#        ['IRN', 'Iran'],
#        ['NL1', 'Netherlands'],
#        ['LIE', 'Liechtenstein'],
#        ['CIV', 'Ivory Coast'],
#        ['SRB', 'Republic of Serbia'],
#        ['MLI', 'Mali'],
#        ['SEN', 'Senegal'],
#        ['NGA', 'Nigeria'],
#        ['BEN', 'Benin'],
#        ['AGO', 'Angola'],
#        ['HRV', 'Croatia'],
#        ['SVN', 'Slovenia'],
#        ['QAT', 'Qatar'],
#        ['SAU', 'Saudi Arabia'],
#        ['BWA', 'Botswana'],
#        ['ZWE', 'Zimbabwe'],
#        ['PAK', 'Pakistan'],
#        ['BGR', 'Bulgaria'],
#        ['THA', 'Thailand'],
#        ['SMR', 'San Marino'],
#        ['HTI', 'Haiti'],
#        ['DOM', 'Dominican Republic'],
#        ['TCD', 'Chad'],
#        ['KWT', 'Kuwait'],
#        ['SLV', 'El Salvador'],
#        ['GTM', 'Guatemala'],
#        ['TLS', 'East Timor'],
#        ['BRN', 'Brunei'],
#        ['MCO', 'Monaco'],
#        ['DZA', 'Algeria'],
#        ['MOZ', 'Mozambique'],
#        ['SWZ', 'eSwatini'],
#        ['BDI', 'Burundi'],
#        ['RWA', 'Rwanda'],
#        ['MMR', 'Myanmar'],
#        ['BGD', 'Bangladesh'],
#        ['AND', 'Andorra'],
#        ['AFG', 'Afghanistan'],
#        ['MNE', 'Montenegro'],
#        ['BIH', 'Bosnia and Herzegovina'],
#        ['UGA', 'Uganda'],
#        ['CUB', 'Cuba'],
#        ['CUB', 'Cuba'],
#        ['HND', 'Honduras'],
#        ['ECU', 'Ecuador'],
#        ['COL', 'Colombia'],
#        ['PRY', 'Paraguay'],
#        ['BRI', 'Brazilian Island'],
#        ['PRT', 'Portugal'],
#        ['MDA', 'Moldova'],
#        ['TKM', 'Turkmenistan'],
#        ['JOR', 'Jordan'],
#        ['NPL', 'Nepal'],
#        ['LSO', 'Lesotho'],
#        ['CMR', 'Cameroon'],
#        ['GAB', 'Gabon'],
#        ['NER', 'Niger'],
#        ['BFA', 'Burkina Faso'],
#        ['TGO', 'Togo'],
#        ['GHA', 'Ghana'],
#        ['GNB', 'Guinea-Bissau'],
#        ['GBR', 'United Kingdom'],
#        ['USA', 'United States of America'],
#        ['CAN', 'Canada'],
#        ['MEX', 'Mexico'],
#        ['BLZ', 'Belize'],
#        ['PAN', 'Panama'],
#        ['VEN', 'Venezuela'],
#        ['PNG', 'Papua New Guinea'],
#        ['EGY', 'Egypt'],
#        ['YEM', 'Yemen'],
#        ['MRT', 'Mauritania'],
#        ['GNQ', 'Equatorial Guinea'],
#        ['GMB', 'Gambia'],
#        ['CHN', 'China'],
#        ['VAT', 'Vatican'],
#        ['CYN', 'Northern Cyprus'],
#        ['CNM', 'Cyprus No Mans Area'],
#        ['KAS', 'Kashmir'],
#        ['KAZ', 'Kazakhstan'],
#        ['GBR', 'United Kingdom'],
#        ['SPI', 'Southern Patagonian Ice Field'],
#        ['BRT', 'Bir Tawil'],
#        ['ATA', 'Antarctica'],
#        ['AUS', 'Australia'],
#        ['DN1', 'Denmark'],
#        ['FJI', 'Fiji'],
#        ['NZL', 'New Zealand'],
#        ['FRA', 'France'],
#        ['MDG', 'Madagascar'],
#        ['PHL', 'Philippines'],
#        ['LKA', 'Sri Lanka'],
#        ['NL1', 'Netherlands'],
#        ['NL1', 'Netherlands'],
#        ['BHS', 'The Bahamas'],
#        ['GBR', 'United Kingdom'],
#        ['TWN', 'Taiwan'],
#        ['JPN', 'Japan'],
#        ['FRA', 'France'],
#        ['ISL', 'Iceland'],
#        ['GBR', 'United Kingdom'],
#        ['FRA', 'France'],
#        ['FRA', 'France'],
#        ['SYC', 'Seychelles'],
#        ['KIR', 'Kiribati'],
#        ['MHL', 'Marshall Islands'],
#        ['TTO', 'Trinidad and Tobago'],
#        ['GRD', 'Grenada'],
#        ['VCT', 'Saint Vincent and the Grenadines'],
#        ['BRB', 'Barbados'],
#        ['LCA', 'Saint Lucia'],
#        ['DMA', 'Dominica'],
#        ['USA', 'United States of America'],
#        ['GBR', 'United Kingdom'],
#        ['ATG', 'Antigua and Barbuda'],
#        ['KNA', 'Saint Kitts and Nevis'],
#        ['USA', 'United States of America'],
#        ['FRA', 'France'],
#        ['USA', 'United States of America'],
#        ['GBR', 'United Kingdom'],
#        ['GBR', 'United Kingdom'],
#        ['JAM', 'Jamaica'],
#        ['GBR', 'United Kingdom'],
#        ['GBR', 'United Kingdom'],
#        ['AUS', 'Australia'],
#        ['GBR', 'United Kingdom'],
#        ['MUS', 'Mauritius'],
#        ['COM', 'Comoros'],
#        ['STP', 'São Tomé and Principe'],
#        ['CPV', 'Cabo Verde'],
#        ['MLT', 'Malta'],
#        ['GBR', 'United Kingdom'],
#        ['GBR', 'United Kingdom'],
#        ['GBR', 'United Kingdom'],
#        ['FI1', 'Finland'],
#        ['DN1', 'Denmark'],
#        ['AUS', 'Australia'],
#        ['GBR', 'United Kingdom'],
#        ['SGP', 'Singapore'],
#        ['AUS', 'Australia'],
#        ['NZL', 'New Zealand'],
#        ['TON', 'Tonga'],
#        ['FRA', 'France'],
#        ['WSM', 'Samoa'],
#        ['SLB', 'Solomon Islands'],
#        ['TUV', 'Tuvalu'],
#        ['MDV', 'Maldives'],
#        ['NRU', 'Nauru'],
#        ['FSM', 'Federated States of Micronesia'],
#        ['GBR', 'United Kingdom'],
#        ['GBR', 'United Kingdom'],
#        ['VUT', 'Vanuatu'],
#        ['NZL', 'New Zealand'],
#        ['USA', 'United States of America'],
#        ['PLW', 'Palau'],
#        ['USA', 'United States of America'],
#        ['USA', 'United States of America'],
#        ['BHR', 'Bahrain'],
#        ['AUS', 'Australia'],
#        ['PGA', 'Spratly Islands'],
#        ['FRA', 'France'],
#        ['CHN', 'China'],
#        ['AUS', 'Australia'],
#        ['BJN', 'Bajo Nuevo Bank (Petrel Is.)'],
#        ['SER', 'Serranilla Bank'],
#        ['SCR', 'Scarborough Reef']], dtype=object)

# %%
df_countries_usgs=pd.read_csv('merged_countries.csv',sep=',')

# %%
df_geo_usgs= gpd.GeoDataFrame(df_countries_usgs, geometry=gpd.points_from_xy(df_countries_usgs.longitude, df_countries_usgs.latitude))

# %%
df_geo_usgs.head()
# Out:
#    Unnamed: 0                    geometry souvereign  admin  index_right  \
# 0           0  POINT (-74.46600 -8.49800)       Peru   Peru        65172
# 1       13753  POINT (-74.46600 -8.49800)       Peru   Peru        65172
# 2           0  POINT (-74.46600 -8.49800)       Peru   Peru            1
# 3       13753  POINT (-74.46600 -8.49800)       Peru   Peru            1
# 4           1  POINT (110.73600 35.51500)      China  China           12
#
#                         time  latitude  longitude  depth  mag          id  \
# 0  2010-01-25 00:00:00+00:00    -8.498    -74.466  146.7  5.9  usp000h6md
# 1  2010-01-25 00:00:00+00:00    -8.498    -74.466  146.7  5.9  usp000h6md
# 2  2010-01-25 00:00:00+00:00    -8.498    -74.466  146.7  5.9  usp000h6md
# 3  2010-01-25 00:00:00+00:00    -8.498    -74.466  146.7  5.9  usp000h6md
# 4  2010-01-24 00:00:00+00:00    35.515    110.736   28.7  5.0  usp000h6j0
#
#                             place        Date
# 0  13 km SE of San Fernando, Peru  2010-01-25
# 1  13 km SE of San Fernando, Peru  2010-01-25
# 2  13 km SE of San Fernando, Peru  2010-01-25
# 3  13 km SE of San Fernando, Peru  2010-01-25
# 4    28 km ENE of Hancheng, China  2010-01-24

# %%
df_geo_usgs=df_geo_usgs.drop(columns=['Unnamed: 0', 'index_right'])

drop_countries = list(set(countries_df.columns)-set(['id','SOVEREIGNT','country code', 'geometry']))

countries_df=countries_df.drop(columns=drop_countries)

# %%
#df_country_codes = gpd.sjoin(usgs_country_code, df_geo_usgs, how="inner")
df_usgs_codes = gpd.sjoin(df_geo_usgs, countries_df, how="inner")
# Out:
# <ipython-input-12-97638a1b7b3d>:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   df_usgs_codes = gpd.sjoin(df_geo_usgs, countries_df, how="inner")

# %%
df_usgs_codes.head()
# Out:
#                       geometry souvereign admin                       time  \
# 0   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 1   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 2   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 3   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 97  POINT (-77.71800 -8.80200)       Peru  Peru  2010-01-03 00:00:00+00:00
#
#     latitude  longitude  depth  mag          id  \
# 0     -8.498    -74.466  146.7  5.9  usp000h6md
# 1     -8.498    -74.466  146.7  5.9  usp000h6md
# 2     -8.498    -74.466  146.7  5.9  usp000h6md
# 3     -8.498    -74.466  146.7  5.9  usp000h6md
# 97    -8.802    -77.718  116.8  5.7  usp000h5na
#
#                              place        Date  index_right SOVEREIGNT  \
# 0   13 km SE of San Fernando, Peru  2010-01-25            4       Peru
# 1   13 km SE of San Fernando, Peru  2010-01-25            4       Peru
# 2   13 km SE of San Fernando, Peru  2010-01-25            4       Peru
# 3   13 km SE of San Fernando, Peru  2010-01-25            4       Peru
# 97      16 km E of Huallanca, Peru  2010-01-03            4       Peru
#
#    country code
# 0           PER
# 1           PER
# 2           PER
# 3           PER
# 97          PER

# %%
df_usgs_codes =df_usgs_codes.rename(columns={'SOVEREIGNT':'country', 'Date':'date'})

df_usgs_codes.head()
# Out:
#                       geometry souvereign admin                       time  \
# 0   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 1   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 2   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 3   POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 97  POINT (-77.71800 -8.80200)       Peru  Peru  2010-01-03 00:00:00+00:00
#
#     latitude  longitude  depth  mag          id  \
# 0     -8.498    -74.466  146.7  5.9  usp000h6md
# 1     -8.498    -74.466  146.7  5.9  usp000h6md
# 2     -8.498    -74.466  146.7  5.9  usp000h6md
# 3     -8.498    -74.466  146.7  5.9  usp000h6md
# 97    -8.802    -77.718  116.8  5.7  usp000h5na
#
#                              place        date  index_right country  \
# 0   13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 1   13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 2   13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 3   13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 97      16 km E of Huallanca, Peru  2010-01-03            4    Peru
#
#    country code
# 0           PER
# 1           PER
# 2           PER
# 3           PER
# 97          PER

# %% [markdown]
# Finally, we still merge this dataset to the [USGS Earth and Monitoring dataset](https://www.usgs.gov/programs/earthquake-hazards/data) which contains another relevant feature for our models.

# %%
shaking_data = pd.read_csv('usgs_shaking.csv')

# %%
shaking_data.head()
# Out:
#    Unnamed: 0          id                           place          time  mag  \
# 0           0  usp00043zh      20 km SE of Atiquipa, Peru  631703203440  5.5
# 1           1  usp0004417      86 km NNW of Mangan, India  631852166690  5.5
# 2           2  usp0004421     120 km E of W?ngjing, India  631911089210  6.3
# 3           3  usp000443d  25 km ENE of Kupang, Indonesia  631987906730  5.5
# 4           4  usp0004453     near the coast of Nicaragua  632114699080  5.6
#
#      mmi                                   geometry
# 0  4.519               POINT Z (-74.245 -15.947 48)
# 1  4.066  POINT Z (88.163 28.225 79.09999999999999)
# 2  4.782              POINT Z (95.241 24.753 119.2)
# 3  5.051             POINT Z (123.819 -10.073 32.7)
# 4  4.146              POINT Z (-87.489 12.672 86.2)

# %%
print(len(shaking_data))
shaking_data['mmi'].isna().sum()
# Out:
# 27829
# 13813

# %%
#merge to the usgs dataset
df_usgs_clean= pd.merge(df_usgs_codes, shaking_data[['id', 'mmi']], how= 'left', on='id')
df_usgs_clean.head(50)
# Out:
#                        geometry souvereign admin                       time  \
# 0    POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 1    POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 2    POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 3    POINT (-74.46600 -8.49800)       Peru  Peru  2010-01-25 00:00:00+00:00
# 4    POINT (-77.71800 -8.80200)       Peru  Peru  2010-01-03 00:00:00+00:00
# 5   POINT (-73.97800 -15.76600)       Peru  Peru  2009-12-24 00:00:00+00:00
# 6    POINT (-80.21000 -4.60200)       Peru  Peru  2009-10-15 00:00:00+00:00
# 7   POINT (-70.24800 -15.12100)       Peru  Peru  2009-09-05 00:00:00+00:00
# 8   POINT (-75.48900 -14.30100)       Peru  Peru  2009-08-03 00:00:00+00:00
# 9   POINT (-75.40600 -12.09700)       Peru  Peru  2009-08-01 00:00:00+00:00
# 10  POINT (-70.44500 -15.04100)       Peru  Peru  2009-07-12 00:00:00+00:00
# 11  POINT (-76.13300 -13.56300)       Peru  Peru  2009-06-15 00:00:00+00:00
# 12  POINT (-70.80400 -17.36000)       Peru  Peru  2009-06-13 00:00:00+00:00
# 13   POINT (-74.67900 -8.62900)       Peru  Peru  2009-06-06 00:00:00+00:00
# 14  POINT (-75.98300 -14.41700)       Peru  Peru  2009-05-26 00:00:00+00:00
# 15  POINT (-70.36500 -14.45200)       Peru  Peru  2009-03-15 00:00:00+00:00
# 16   POINT (-80.89100 -5.85400)       Peru  Peru  2009-02-15 00:00:00+00:00
# 17   POINT (-73.99300 -8.51700)       Peru  Peru  2009-02-13 00:00:00+00:00
# 18   POINT (-75.87200 -8.82300)       Peru  Peru  2008-12-31 00:00:00+00:00
# 19  POINT (-73.45300 -15.86700)       Peru  Peru  2008-11-27 00:00:00+00:00
# 20   POINT (-75.66400 -9.06900)       Peru  Peru  2008-11-22 00:00:00+00:00
# 21   POINT (-74.43100 -7.79600)       Peru  Peru  2008-11-19 00:00:00+00:00
# 22  POINT (-71.99100 -15.00400)       Peru  Peru  2008-10-15 00:00:00+00:00
# 23  POINT (-73.63000 -16.12500)       Peru  Peru  2008-09-20 00:00:00+00:00
# 24   POINT (-74.37700 -7.64100)       Peru  Peru  2008-08-26 00:00:00+00:00
# 25   POINT (-74.26800 -8.35600)       Peru  Peru  2008-08-22 00:00:00+00:00
# 26   POINT (-80.92400 -5.84500)       Peru  Peru  2008-08-18 00:00:00+00:00
# 27  POINT (-71.74800 -15.98600)       Peru  Peru  2008-07-08 00:00:00+00:00
# 28  POINT (-75.51200 -10.36800)       Peru  Peru  2008-07-01 00:00:00+00:00
# 29   POINT (-75.58400 -8.91900)       Peru  Peru  2008-06-26 00:00:00+00:00
# 30   POINT (-75.62900 -8.90300)       Peru  Peru  2008-06-26 00:00:00+00:00
# 31   POINT (-76.44800 -8.73300)       Peru  Peru  2008-06-05 00:00:00+00:00
# 32  POINT (-74.46200 -13.10200)       Peru  Peru  2008-05-28 00:00:00+00:00
# 33   POINT (-74.88600 -8.58000)       Peru  Peru  2008-05-20 00:00:00+00:00
# 34  POINT (-70.20600 -17.47700)       Peru  Peru  2008-03-07 00:00:00+00:00
# 35  POINT (-72.26900 -15.31100)       Peru  Peru  2008-02-13 00:00:00+00:00
# 36  POINT (-74.73300 -15.17200)       Peru  Peru  2008-01-18 00:00:00+00:00
# 37  POINT (-75.49000 -14.79500)       Peru  Peru  2007-12-31 00:00:00+00:00
# 38  POINT (-75.42900 -14.79000)       Peru  Peru  2007-12-31 00:00:00+00:00
# 39  POINT (-70.21300 -17.56300)       Peru  Peru  2007-12-04 00:00:00+00:00
# 40  POINT (-75.28500 -12.07900)       Peru  Peru  2007-10-24 00:00:00+00:00
# 41  POINT (-76.12000 -13.57300)       Peru  Peru  2007-10-09 00:00:00+00:00
# 42  POINT (-71.31600 -12.68600)       Peru  Peru  2007-09-24 00:00:00+00:00
# 43  POINT (-73.72600 -16.03500)       Peru  Peru  2007-09-20 00:00:00+00:00
# 44   POINT (-74.51800 -8.83500)       Peru  Peru  2007-09-17 00:00:00+00:00
# 45  POINT (-69.66300 -17.28100)       Peru  Peru  2007-09-10 00:00:00+00:00
# 46  POINT (-76.29100 -13.80500)       Peru  Peru  2007-08-18 00:00:00+00:00
# 47  POINT (-76.09300 -14.17700)       Peru  Peru  2007-08-17 00:00:00+00:00
# 48  POINT (-76.08700 -14.21100)       Peru  Peru  2007-08-17 00:00:00+00:00
# 49  POINT (-75.97800 -14.45900)       Peru  Peru  2007-08-17 00:00:00+00:00
#
#     latitude  longitude  depth  mag          id  \
# 0     -8.498    -74.466  146.7  5.9  usp000h6md
# 1     -8.498    -74.466  146.7  5.9  usp000h6md
# 2     -8.498    -74.466  146.7  5.9  usp000h6md
# 3     -8.498    -74.466  146.7  5.9  usp000h6md
# 4     -8.802    -77.718  116.8  5.7  usp000h5na
# 5    -15.766    -73.978   59.1  5.6  usp000h5aq
# 6     -4.602    -80.210   62.2  5.0  usp000h2z1
# 7    -15.121    -70.248  210.2  5.8  usp000h18a
# 8    -14.301    -75.489   45.4  5.3  usp000gzyk
# 9    -12.097    -75.406  101.3  5.2  usp000gzwe
# 10   -15.041    -70.445  198.9  6.1  usp000gz5d
# 11   -13.563    -76.133   42.2  5.4  usp000gy82
# 12   -17.360    -70.804   61.4  5.2  usp000gy5f
# 13    -8.629    -74.679  133.8  5.2  usp000gxy6
# 14   -14.417    -75.983   14.8  5.4  usp000gxhs
# 15   -14.452    -70.365  189.7  5.7  usp000gv0b
# 16    -5.854    -80.891   21.0  6.1  usp000gu0z
# 17    -8.517    -73.993  157.0  5.2  usp000gtwv
# 18    -8.823    -75.872   32.5  5.0  usp000gry2
# 19   -15.867    -73.453   75.3  5.0  usp000gpha
# 20    -9.069    -75.664   37.9  5.1  usp000gp7x
# 21    -7.796    -74.431  149.8  5.3  usp000gp1e
# 22   -15.004    -71.991  137.3  5.0  usp000gk9b
# 23   -16.125    -73.630   40.5  5.4  usp000ghdz
# 24    -7.641    -74.377  154.0  6.4  usp000gfmr
# 25    -8.356    -74.268  148.6  5.2  usp000gf9j
# 26    -5.845    -80.924   48.5  5.1  usp000geym
# 27   -15.986    -71.748  123.0  6.2  usp000gbn0
# 28   -10.368    -75.512   32.7  5.4  usp000gb1b
# 29    -8.919    -75.584   39.7  5.2  usp000gamk
# 30    -8.903    -75.629   38.1  5.0  usp000gak5
# 31    -8.733    -76.448  126.2  5.2  usp000g8mx
# 32   -13.102    -74.462   84.2  5.2  usp000g805
# 33    -8.580    -74.886  129.5  5.2  usp000g7bx
# 34   -17.477    -70.206   82.6  5.2  usp000g0xy
# 35   -15.311    -72.269  115.6  5.2  usp000fytb
# 36   -15.172    -74.733   53.8  5.0  usp000fwzr
# 37   -14.795    -75.490   32.3  5.0  usp000fvqh
# 38   -14.790    -75.429   27.7  5.2  usp000fvqd
# 39   -17.563    -70.213   46.4  5.1  usp000ftuv
# 40   -12.079    -75.285  105.9  5.0  usp000fr66
# 41   -13.573    -76.120   49.6  5.0  usp000fq5s
# 42   -12.686    -71.316   27.9  5.1  usp000fnzy
# 43   -16.035    -73.726   58.3  5.1  usp000fnrt
# 44    -8.835    -74.518  142.7  5.2  usp000fnh7
# 45   -17.281    -69.663   44.8  5.2  usp000fmtb
# 46   -13.805    -76.291   30.0  6.0  usp000fk32
# 47   -14.177    -76.093   19.8  5.6  usp000fk0g
# 48   -14.211    -76.087   20.1  5.0  usp000fjzt
# 49   -14.459    -75.978   46.8  5.4  usp000fjzc
#
#                                place        date  index_right country  \
# 0     13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 1     13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 2     13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 3     13 km SE of San Fernando, Peru  2010-01-25            4    Peru
# 4         16 km E of Huallanca, Peru  2010-01-03            4    Peru
# 5         4 km NNW of Achanizo, Peru  2009-12-24            4    Peru
# 6         6 km NE of Las Lomas, Peru  2009-10-15            4    Peru
# 7           12 km N of Nicasio, Peru  2009-09-05            4    Peru
# 8        27 km ESE of Santiago, Peru  2009-08-03            4    Peru
# 9         8 km SSW of Chambara, Peru  2009-08-01            4    Peru
# 10       10 km SSW of Tirapata, Peru  2009-07-12            4    Peru
# 11     11 km N of San Clemente, Peru  2009-06-15            4    Peru
# 12     20 km SE of San Antonio, Peru  2009-06-13            4    Peru
# 13        15 km NNE of Honoria, Peru  2009-06-06            4    Peru
# 14        38 km SW of Santiago, Peru  2009-05-26            4    Peru
# 15            29 km E of Nuñoa, Peru  2009-03-15            4    Peru
# 16   near the coast of northern Peru  2009-02-15            4    Peru
# 17   61 km ESE of San Fernando, Peru  2009-02-13            4    Peru
# 18    53 km NNE of Tingo María, Peru  2008-12-31            4    Peru
# 19        35 km WNW of Urasqui, Peru  2008-11-27            4    Peru
# 20     44 km NE of Tingo María, Peru  2008-11-22            4    Peru
# 21       65 km NNE of Pucallpa, Peru  2008-11-19            4    Peru
# 22         36 km S of Cayarani, Peru  2008-10-15            4    Peru
# 23             9 km N of Atico, Peru  2008-09-20            4    Peru
# 24      78 km ESE of Contamana, Peru  2008-08-26            4    Peru
# 25     30 km E of San Fernando, Peru  2008-08-22            4    Peru
# 26        33 km SSW of Sechura, Peru  2008-08-18            4    Peru
# 27            28 km E of Lluta, Peru  2008-07-08            4    Peru
# 28       26 km NNW of Oxapampa, Peru  2008-07-01            4    Peru
# 29  41 km WSW of San Alejandro, Peru  2008-06-26            4    Peru
# 30                      central Peru  2008-06-26            4    Peru
# 31           30 km S of Uchiza, Peru  2008-06-05            4    Peru
# 32       6 km WSW of Antaparco, Peru  2008-05-28            4    Peru
# 33     14 km SW of Campo Verde, Peru  2008-05-20            4    Peru
# 34      2 km NNE of Chipispaya, Peru  2008-03-07            4    Peru
# 35       9 km ESE of Orcopampa, Peru  2008-02-13            4    Peru
# 36          30 km NNW of Acarí, Peru  2008-01-18            4    Peru
# 37     32 km WSW of Changuillo, Peru  2007-12-31            4    Peru
# 38     26 km WSW of Changuillo, Peru  2007-12-31            4    Peru
# 39        7 km S of Chipispaya, Peru  2007-12-04            4    Peru
# 40           1 km S of Chupaca, Peru  2007-10-24            4    Peru
# 41   10 km NNE of San Clemente, Peru  2007-10-09            4    Peru
# 42      17 km NNE of Salvación, Peru  2007-09-24            4    Peru
# 43          22 km NNW of Atico, Peru  2007-09-20            4    Peru
# 44        22 km ESE of Honoria, Peru  2007-09-17            4    Peru
# 45       40 km E of Chuquitira, Peru  2007-09-10            4    Peru
# 46         7 km NNW of Paracas, Peru  2007-08-18            4    Peru
# 47    near the coast of central Peru  2007-08-17            4    Peru
# 48         40 km W of Santiago, Peru  2007-08-17            4    Peru
# 49        41 km SW of Santiago, Peru  2007-08-17            4    Peru
#
#    country code    mmi
# 0           PER    NaN
# 1           PER    NaN
# 2           PER    NaN
# 3           PER    NaN
# 4           PER    NaN
# 5           PER  4.461
# 6           PER    NaN
# 7           PER    NaN
# 8           PER    NaN
# 9           PER    NaN
# 10          PER    NaN
# 11          PER    NaN
# 12          PER    NaN
# 13          PER    NaN
# 14          PER    NaN
# 15          PER    NaN
# 16          PER  6.367
# 17          PER    NaN
# 18          PER    NaN
# 19          PER    NaN
# 20          PER    NaN
# 21          PER    NaN
# 22          PER    NaN
# 23          PER    NaN
# 24          PER  4.371
# 25          PER    NaN
# 26          PER    NaN
# 27          PER  4.446
# 28          PER  5.379
# 29          PER    NaN
# 30          PER    NaN
# 31          PER    NaN
# 32          PER    NaN
# 33          PER    NaN
# 34          PER    NaN
# 35          PER    NaN
# 36          PER    NaN
# 37          PER    NaN
# 38          PER    NaN
# 39          PER    NaN
# 40          PER    NaN
# 41          PER    NaN
# 42          PER    NaN
# 43          PER    NaN
# 44          PER    NaN
# 45          PER    NaN
# 46          PER  5.938
# 47          PER  5.797
# 48          PER    NaN
# 49          PER    NaN

# %%
#drop columns
df_usgs_clean=df_usgs_clean.drop(columns=['index_right','geometry', 'souvereign', 'admin', 'latitude', 'longitude', 'id', 'place', 'time'])

#drop earthquake duplicates US-GS dataset
print(len(df_usgs_clean))
df_usgs_clean.drop_duplicates(inplace=True)
print(len(df_usgs_clean))

#missing values for mmi
print('missing mmi values:', 100*(df_usgs_clean['mmi'].isna().sum()/len(df_usgs_clean)))

df_usgs_clean.head()
# Out:
# 17090
# 16777
# missing mmi values: 67.09185194015616
#    depth  mag        date country country code    mmi
# 0  146.7  5.9  2010-01-25    Peru          PER    NaN
# 4  116.8  5.7  2010-01-03    Peru          PER    NaN
# 5   59.1  5.6  2009-12-24    Peru          PER  4.461
# 6   62.2  5.0  2009-10-15    Peru          PER    NaN
# 7  210.2  5.8  2009-09-05    Peru          PER    NaN

# %%
# save usgs dataset to csv

df_usgs_clean.to_csv(r'df_usgs_clean.csv')

# %% [markdown]
# # EMDAT Dataset
#
# Now we merge the data to the [EMDAT dataset](https://www.emdat.be/) for international disasters which was already cleaned to only have Earthquake data.

# %%
df_emdat=pd.read_csv('emdat_date.csv',sep=',')
df_emdat.head(100)
# Out:
#     Unnamed: 0         Dis No  Year  Month   Day Disaster Type  \
# 0           63  1960-0013-CHL  1960    5.0  22.0    Earthquake
# 1           64  1960-0033-DZA  1960    2.0  21.0    Earthquake
# 2           65  1961-0016-ETH  1961    6.0   2.0    Earthquake
# 3           66  1962-0044-ALB  1962    3.0  18.0    Earthquake
# 4           67  1962-0030-COL  1962    7.0  30.0    Earthquake
# ..         ...            ...   ...    ...   ...           ...
# 95         265  1971-0034-TUR  1971    5.0  22.0    Earthquake
# 96         266  1971-0016-USA  1971    2.0   9.0    Earthquake
# 97         267  1972-0027-IRN  1972    4.0  10.0    Earthquake
# 98         268  1972-0084-ITA  1972    2.0   4.0    Earthquake
# 99         269  1972-0067-NIC  1972   12.0  23.0    Earthquake
#
#    Disaster Subtype                         Country Country Code  \
# 0           Tsunami                           Chile          CHL
# 1   Ground movement                         Algeria          DZA
# 2   Ground movement                        Ethiopia          ETH
# 3   Ground movement                         Albania          ALB
# 4   Ground movement                        Colombia          COL
# ..              ...                             ...          ...
# 95  Ground movement                          Turkey          TUR
# 96  Ground movement  United States of America (the)          USA
# 97  Ground movement      Iran (Islamic Republic of)          IRN
# 98  Ground movement                           Italy          ITA
# 99  Ground movement                       Nicaragua          NIC
#
#               Region  ... No Homeless Total Affected  \
# 0      South America  ...         NaN      2003000.0
# 1    Northern Africa  ...      1250.0         1250.0
# 2     Eastern Africa  ...         NaN            NaN
# 3    Southern Europe  ...         NaN          154.0
# 4      South America  ...         NaN          300.0
# ..               ...  ...         ...            ...
# 95      Western Asia  ...     27465.0        88665.0
# 96  Northern America  ...         NaN         2000.0
# 97     Southern Asia  ...         NaN        23458.0
# 98   Southern Europe  ...         NaN          450.0
# 99   Central America  ...    300000.0       720000.0
#
#    Reconstruction Costs ('000 US$) Reconstruction Costs, Adjusted ('000 US$)  \
# 0                              NaN                                       NaN
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
# ..                             ...                                       ...
# 95                             NaN                                       NaN
# 96                             NaN                                       NaN
# 97                             NaN                                       NaN
# 98                             NaN                                       NaN
# 99                             NaN                                       NaN
#
#    Insured Damages ('000 US$) Insured Damages, Adjusted ('000 US$)  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
# ..                        ...                                  ...
# 95                        NaN                                  NaN
# 96                    35000.0                             223710.0
# 97                        NaN                                  NaN
# 98                        NaN                                  NaN
# 99                   100000.0                             618919.0
#
#    Total Damages ('000 US$)  Total Damages, Adjusted ('000 US$)        CPI  \
# 0                  550000.0                           4813056.0  11.427251
# 1                       NaN                                 NaN  11.427251
# 2                       NaN                                 NaN  11.549601
# 3                       NaN                                 NaN  11.688060
# 4                       NaN                                 NaN  11.688060
# ..                      ...                                 ...        ...
# 95                   5000.0                             31959.0  15.645257
# 96                 553000.0                           3534617.0  15.645257
# 97                   1000.0                              6189.0  16.157212
# 98                      NaN                                 NaN  16.157212
# 99                 845000.0                           5229863.0  16.157212
#
#           myDt
# 0   1960-05-22
# 1   1960-02-21
# 2   1961-06-02
# 3   1962-03-18
# 4   1962-07-30
# ..         ...
# 95  1971-05-22
# 96  1971-02-09
# 97  1972-04-10
# 98  1972-02-04
# 99  1972-12-23
#
# [100 rows x 35 columns]

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 1235 non-null   int64
#  1   Dis No                                     1235 non-null   object
#  2   Year                                       1235 non-null   int64
#  3   Month                                      1235 non-null   float64
#  4   Day                                        1235 non-null   float64
#  5   Disaster Type                              1235 non-null   object
#  6   Disaster Subtype                           1233 non-null   object
#  7   Country                                    1235 non-null   object
#  8   Country Code                               1235 non-null   object
#  9   Region                                     1235 non-null   object
#  10  Continent                                  1235 non-null   object
#  11  Location                                   1222 non-null   object
#  12  Associated Dis                             269 non-null    object
#  13  Associated Dis2                            33 non-null     object
#  14  OFDA Response                              200 non-null    object
#  15  Appeal                                     265 non-null    object
#  16  Declaration                                280 non-null    object
#  17  Aid Contribution                           100 non-null    float64
#  18  Dis Mag Value                              1203 non-null   float64
#  19  Latitude                                   1204 non-null   object
#  20  Longitude                                  1202 non-null   object
#  21  Local Time                                 818 non-null    object
#  22  Total Deaths                               870 non-null    float64
#  23  No Injured                                 935 non-null    float64
#  24  No Affected                                779 non-null    float64
#  25  No Homeless                                388 non-null    float64
#  26  Total Affected                             1136 non-null   float64
#  27  Reconstruction Costs ('000 US$)            8 non-null      float64
#  28  Reconstruction Costs, Adjusted ('000 US$)  8 non-null      float64
#  29  Insured Damages ('000 US$)                 99 non-null     float64
#  30  Insured Damages, Adjusted ('000 US$)       98 non-null     float64
#  31  Total Damages ('000 US$)                   536 non-null    float64
#  32  Total Damages, Adjusted ('000 US$)         525 non-null    float64
#  33  CPI                                        1206 non-null   float64
#  34  myDt                                       1235 non-null   object
# dtypes: float64(16), int64(2), object(17)
# memory usage: 337.8+ KB

# %%
# copy dataset for preprocessing

df_emdat_processing = df_emdat.copy()

# %%
df_emdat_processing.columns
# Out:
# Index(['Unnamed: 0', 'Dis No', 'Year', 'Month', 'Day', 'Disaster Type',
#        'Disaster Subtype', 'Country', 'Country Code', 'Region', 'Continent',
#        'Location', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'Aid Contribution', 'Dis Mag Value',
#        'Latitude', 'Longitude', 'Local Time', 'Total Deaths', 'No Injured',
#        'No Affected', 'No Homeless', 'Total Affected',
#        'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damages ('000 US$)', 'Insured Damages, Adjusted ('000 US$)',
#        'Total Damages ('000 US$)', 'Total Damages, Adjusted ('000 US$)', 'CPI',
#        'myDt'],
#       dtype='object')

# %%
drop_emdat = list(set(df_emdat_processing.columns)-
                  set(['Year','Country', 'Country Code', 'Continent', 
                       'Total Affected','CPI','myDt']))

df_emdat_processing = df_emdat_processing.drop(columns=drop_emdat)
df_emdat_processing.head()
# Out:
#    Year   Country Country Code Continent  Total Affected        CPI  \
# 0  1960     Chile          CHL  Americas       2003000.0  11.427251
# 1  1960   Algeria          DZA    Africa          1250.0  11.427251
# 2  1961  Ethiopia          ETH    Africa             NaN  11.549601
# 3  1962   Albania          ALB    Europe           154.0  11.688060
# 4  1962  Colombia          COL  Americas           300.0  11.688060
#
#          myDt
# 0  1960-05-22
# 1  1960-02-21
# 2  1961-06-02
# 3  1962-03-18
# 4  1962-07-30

# %%
# Dropping missing vaues for Total affected

print(len(df_emdat_processing))
df_emdat_processing.dropna(subset=['Total Affected'], inplace=True)
print(len(df_emdat_processing))
# Out:
# 1235
# 1136

# %%
df_emdat_processing =df_emdat_processing.rename(columns={'myDt':'date', 'Country Code':'country code'})

df_emdat_clean = df_emdat_processing
df_emdat_clean.head()
# Out:
#    Year         Country country code Continent  Total Affected        CPI  \
# 0  1960           Chile          CHL  Americas       2003000.0  11.427251
# 1  1960         Algeria          DZA    Africa          1250.0  11.427251
# 3  1962         Albania          ALB    Europe           154.0  11.688060
# 4  1962        Colombia          COL  Americas           300.0  11.688060
# 5  1964  Azores Islands          AZO    Europe          1000.0  11.984281
#
#          date
# 0  1960-05-22
# 1  1960-02-21
# 3  1962-03-18
# 4  1962-07-30
# 5  1964-02-18

# %%
df_merged_emdat_usgs= df_emdat_clean.merge(df_usgs_clean, how= 'inner', on=['date', 'country code'])

# %%
df_merged_emdat_usgs.head()
# Out:
#    Year Country country code Continent  Total Affected        CPI        date  \
# 0  1960   Chile          CHL  Americas       2003000.0  11.427251  1960-05-22
# 1  1960   Chile          CHL  Americas       2003000.0  11.427251  1960-05-22
# 2  1960   Chile          CHL  Americas       2003000.0  11.427251  1960-05-22
# 3  1960   Chile          CHL  Americas       2003000.0  11.427251  1960-05-22
# 4  1960   Chile          CHL  Americas       2003000.0  11.427251  1960-05-22
#
#    depth  mag country    mmi
# 0   25.0  9.5   Chile  8.842
# 1   25.0  7.8   Chile  7.274
# 2   25.0  6.8   Chile  6.925
# 3   25.0  7.1   Chile  7.112
# 4   25.0  5.8   Chile  5.841

# %%
#drop columns
df_merged_emdat_usgs=df_merged_emdat_usgs.drop(columns=['Country'])

# %%
df_merged_emdat_usgs.head()
# Out:
#    Year country code Continent  Total Affected        CPI        date  depth  \
# 0  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 1  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 2  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 3  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 4  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
#
#    mag country    mmi
# 0  9.5   Chile  8.842
# 1  7.8   Chile  7.274
# 2  6.8   Chile  6.925
# 3  7.1   Chile  7.112
# 4  5.8   Chile  5.841

# %%
df_merged_emdat_usgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1253 entries, 0 to 1252
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            1253 non-null   int64
#  1   country code    1253 non-null   object
#  2   Continent       1253 non-null   object
#  3   Total Affected  1253 non-null   float64
#  4   CPI             1253 non-null   float64
#  5   date            1253 non-null   object
#  6   depth           1253 non-null   float64
#  7   mag             1253 non-null   float64
#  8   country         1253 non-null   object
#  9   mmi             853 non-null    float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 107.7+ KB

# %%
df_merged_emdat_usgs.to_csv(r'merged_usgs_emdat.csv')

# %%
df_merged_emdat_usgs['country'].unique()
# Out:
# array(['Chile', 'Albania', 'Colombia', 'Greece', 'France', 'Australia',
#        'Ethiopia', 'Indonesia', 'Costa Rica', 'Afghanistan', 'China',
#        'Ecuador', 'Guatemala', 'Argentina', 'Iran', 'Italy', 'Libya',
#        'Mexico', 'Turkey', 'Taiwan', 'United Republic of Tanzania',
#        'El Salvador', 'Nepal', 'New Zealand', 'Peru',
#        'United States of America', 'Nicaragua', 'Pakistan', 'Philippines',
#        'Iceland', 'Solomon Islands', 'Romania', 'Japan',
#        'Democratic Republic of the Congo', 'South Africa', 'Algeria',
#        'Belgium', 'Guinea', 'Bulgaria', 'Brazil', 'Bangladesh',
#        'Honduras', 'Papua New Guinea', 'India', 'Venezuela', 'Egypt',
#        'Malawi', 'Georgia', 'Myanmar', 'Kyrgyzstan', 'Sudan',
#        'Azerbaijan', 'Bolivia', 'Cyprus', 'Russia', 'Slovenia',
#        'Tajikistan', 'Dominican Republic', 'Panama', 'Morocco',
#        'Mozambique', 'Rwanda', 'Bhutan', 'Haiti', 'Spain',
#        'Republic of Serbia', 'Thailand', 'South Korea', 'North Macedonia',
#        'Iraq'], dtype=object)

# %% [markdown]
# # World Bank Indicators
#
# Using the [Word Bank Indicators (WBI) dataset](https://databank.worldbank.org/source/world-development-indicators), we explore different socioeconomic aspects of countries. For the sake of having only a prototype, we explore only a few indicators which can refer to more general aspects of the country infrastructure.

# %%
df_wbi = pd.read_csv('WBI-dataset.csv')

# %%
country = list(df_wbi['Country Name'].unique())
index = country.index('Zimbabwe')
country = country[:index+1]

# %%
codes = list(df_wbi['Country Code'].dropna().unique())
# Remove 'world' variable
codes = codes[:index+1]

# %%
def wbi_country(code):
    ''' Reshape world bank dataset input
    code: string code of a country'''
    df_wbi_code = df_wbi[df_wbi['Country Code']== code]
    assert len(df_wbi_code) > 0, 'Does not find ' + code
    country = df_wbi_code.iloc[0]['Country Name']

    # Reshaping dataset 
    df_wbi_code=df_wbi_code.drop(columns=['Country Name', 'Country Code']).T
    df_wbi_code.columns = list(df_wbi_code.iloc[0,:])

    # cleaning rows and adding country columns back
    df_wbi_code = df_wbi_code.drop(['Series Name', 'Series Code'])
    df_wbi_code['country'] = country
    df_wbi_code['country code'] = code

    df_wbi_code.index = df_wbi_code.index.map(lambda x: int(x[0:4]))
    df_wbi_code['Year'] = df_wbi_code.index
    df_wbi_code.reset_index(level=0,drop = True, inplace=True)
    return df_wbi_code

# %%
# loop for all countries
dfs = list()

for code in codes:
    dfs.append(wbi_country(code))

wbi_processed = pd.concat(dfs)
wbi_processed.reset_index(inplace=True, drop=True)
wbi_processed.tail()
# Out:
#       Population density (people per sq. km of land area)  \
# 13232                                   36.2681607858343
# 13233                                   36.8013416052734
# 13234                                   37.3240584205764
# 13235                                   37.8582732325191
# 13236                                   38.4203877471888
#
#       Population growth (annual %) Population in largest city  \
# 13232             1.54929408793871                    1504803
# 13233             1.45940581314681                    1509901
# 13234             1.41038154233327                    1515016
# 13235             1.42114188586135                    1521311
# 13236             1.47387141587655                    1529920
#
#       Population in the largest city (% of urban population)  \
# 13232                                   33.2095334652472
# 13233                                   32.8993744786959
# 13234                                   32.5768068056639
# 13235                                   32.2495652710328
# 13236                                   31.9258446966417
#
#       Population, total Rural population  \
# 13232          14030338          9499100
# 13233          14236599          9647147
# 13234          14438812          9788215
# 13235          14645473          9928166
# 13236          14862927         10070822
#
#       Rural population (% of total population) Urban population  \
# 13232                                   67.704          4531238
# 13233                                   67.763          4589452
# 13234                                   67.791          4650597
# 13235                                    67.79          4717307
# 13236                                   67.758          4792105
#
#       Urban population (% of total population)  \
# 13232                                   32.296
# 13233                                   32.237
# 13234                                   32.209
# 13235                                    32.21
# 13236                                   32.242
#
#       Urban population growth (annual %) GDP (constant 2015 US$)  \
# 13232                   1.27409384280022        20114015690.1416
# 13233                   1.27654356252103        21061283685.9496
# 13234                   1.32349714884316        22077324353.2946
# 13235                   1.42424874688139        20720841373.1335
# 13236                   1.57316861683581         19426048165.877
#
#       GDP (current US$) GDP growth (annual %)  \
# 13232       20548678100     0.755869250930601
# 13233  17584890936.6523      4.70949217898975
# 13234  18115543790.7855      4.82421053956361
# 13235  19284289739.0517     -6.14423631439116
# 13236   18051170798.941     -6.24874822378281
#
#       GDP per capita (constant 2015 US$)   country country code  Year
# 13232                   1433.60877622062  Zimbabwe          ZWE  2016
# 13233                   1479.23346812428  Zimbabwe          ZWE  2017
# 13234                   1509.52373452279  Zimbabwe          ZWE  2018
# 13235                   1367.67691490163  Zimbabwe          ZWE  2019
# 13236                   1239.85358358565  Zimbabwe          ZWE  2020

# %%
wbi_processed.to_csv(r'wbi_clean.csv')

# %% [markdown]
# # Final Merge of all datasets
#
# Now we can finally merge all datasets: `usgs_clean`, `emdat_clean` and `wbi_clean`.
#
# The first two datasets are already merged into the `df_merged_emdat_usgs`, which we now need to merge to the final dataset.
#
# To do so, we will merge the datasets on `Year` and `country code`. However, we first need to check if the list of countries in both datasets are consistent.

# %%
# countries that are in the already merged dataset, but not in wbi dataset
diff_country_merged= set(df_merged_emdat_usgs['country']).difference(set(wbi_processed['country']))

# country codes that are in the already merged dataset, but not in wbi dataset
diff_code_merged= set(df_merged_emdat_usgs['country code']).difference(set(wbi_processed['country code']))

print('Countries in merged dataset but not in WBI:', sorted(diff_country_merged))

print('Country codes in merged dataset but not in WBI:', sorted(diff_code_merged))
# Out:
# Countries in merged dataset but not in WBI: ['Democratic Republic of the Congo', 'Egypt', 'Iran', 'Kyrgyzstan', 'Republic of Serbia', 'Russia', 'South Korea', 'Taiwan', 'United Republic of Tanzania', 'United States of America', 'Venezuela']
# Country codes in merged dataset but not in WBI: ['TWN']

# %%
# Countries code dictionary (WB dataset)

codes= list(wbi_processed['country code'][:])
countries= list(wbi_processed['country'][:])
countries_dict= dict()

for (code,country) in zip(codes,countries):
    countries_dict[code]= country
     
pprint(countries_dict)
# Out:
# {'ABW': 'Aruba',
#  'AFG': 'Afghanistan',
#  'AGO': 'Angola',
#  'ALB': 'Albania',
#  'AND': 'Andorra',
#  'ARE': 'United Arab Emirates',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ASM': 'American Samoa',
#  'ATG': 'Antigua and Barbuda',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AZE': 'Azerbaijan',
#  'BDI': 'Burundi',
#  'BEL': 'Belgium',
#  'BEN': 'Benin',
#  'BFA': 'Burkina Faso',
#  'BGD': 'Bangladesh',
#  'BGR': 'Bulgaria',
#  'BHR': 'Bahrain',
#  'BHS': 'Bahamas, The',
#  'BIH': 'Bosnia and Herzegovina',
#  'BLR': 'Belarus',
#  'BLZ': 'Belize',
#  'BMU': 'Bermuda',
#  'BOL': 'Bolivia',
#  'BRA': 'Brazil',
#  'BRB': 'Barbados',
#  'BRN': 'Brunei Darussalam',
#  'BTN': 'Bhutan',
#  'BWA': 'Botswana',
#  'CAF': 'Central African Republic',
#  'CAN': 'Canada',
#  'CHE': 'Switzerland',
#  'CHI': 'Channel Islands',
#  'CHL': 'Chile',
#  'CHN': 'China',
#  'CIV': "Cote d'Ivoire",
#  'CMR': 'Cameroon',
#  'COD': 'Congo, Dem. Rep.',
#  'COG': 'Congo, Rep.',
#  'COL': 'Colombia',
#  'COM': 'Comoros',
#  'CPV': 'Cabo Verde',
#  'CRI': 'Costa Rica',
#  'CUB': 'Cuba',
#  'CUW': 'Curacao',
#  'CYM': 'Cayman Islands',
#  'CYP': 'Cyprus',
#  'CZE': 'Czech Republic',
#  'DEU': 'Germany',
#  'DJI': 'Djibouti',
#  'DMA': 'Dominica',
#  'DNK': 'Denmark',
#  'DOM': 'Dominican Republic',
#  'DZA': 'Algeria',
#  'ECU': 'Ecuador',
#  'EGY': 'Egypt, Arab Rep.',
#  'ERI': 'Eritrea',
#  'ESP': 'Spain',
#  'EST': 'Estonia',
#  'ETH': 'Ethiopia',
#  'FIN': 'Finland',
#  'FJI': 'Fiji',
#  'FRA': 'France',
#  'FRO': 'Faroe Islands',
#  'FSM': 'Micronesia, Fed. Sts.',
#  'GAB': 'Gabon',
#  'GBR': 'United Kingdom',
#  'GEO': 'Georgia',
#  'GHA': 'Ghana',
#  'GIB': 'Gibraltar',
#  'GIN': 'Guinea',
#  'GMB': 'Gambia, The',
#  'GNB': 'Guinea-Bissau',
#  'GNQ': 'Equatorial Guinea',
#  'GRC': 'Greece',
#  'GRD': 'Grenada',
#  'GRL': 'Greenland',
#  'GTM': 'Guatemala',
#  'GUM': 'Guam',
#  'GUY': 'Guyana',
#  'HKG': 'Hong Kong SAR, China',
#  'HND': 'Honduras',
#  'HRV': 'Croatia',
#  'HTI': 'Haiti',
#  'HUN': 'Hungary',
#  'IDN': 'Indonesia',
#  'IMN': 'Isle of Man',
#  'IND': 'India',
#  'IRL': 'Ireland',
#  'IRN': 'Iran, Islamic Rep.',
#  'IRQ': 'Iraq',
#  'ISL': 'Iceland',
#  'ISR': 'Israel',
#  'ITA': 'Italy',
#  'JAM': 'Jamaica',
#  'JOR': 'Jordan',
#  'JPN': 'Japan',
#  'KAZ': 'Kazakhstan',
#  'KEN': 'Kenya',
#  'KGZ': 'Kyrgyz Republic',
#  'KHM': 'Cambodia',
#  'KIR': 'Kiribati',
#  'KNA': 'St. Kitts and Nevis',
#  'KOR': 'Korea, Rep.',
#  'KWT': 'Kuwait',
#  'LAO': 'Lao PDR',
#  'LBN': 'Lebanon',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'LCA': 'St. Lucia',
#  'LIE': 'Liechtenstein',
#  'LKA': 'Sri Lanka',
#  'LSO': 'Lesotho',
#  'LTU': 'Lithuania',
#  'LUX': 'Luxembourg',
#  'LVA': 'Latvia',
#  'MAC': 'Macao SAR, China',
#  'MAF': 'St. Martin (French part)',
#  'MAR': 'Morocco',
#  'MCO': 'Monaco',
#  'MDA': 'Moldova',
#  'MDG': 'Madagascar',
#  'MDV': 'Maldives',
#  'MEX': 'Mexico',
#  'MHL': 'Marshall Islands',
#  'MKD': 'North Macedonia',
#  'MLI': 'Mali',
#  'MLT': 'Malta',
#  'MMR': 'Myanmar',
#  'MNE': 'Montenegro',
#  'MNG': 'Mongolia',
#  'MNP': 'Northern Mariana Islands',
#  'MOZ': 'Mozambique',
#  'MRT': 'Mauritania',
#  'MUS': 'Mauritius',
#  'MWI': 'Malawi',
#  'MYS': 'Malaysia',
#  'NAM': 'Namibia',
#  'NCL': 'New Caledonia',
#  'NER': 'Niger',
#  'NGA': 'Nigeria',
#  'NIC': 'Nicaragua',
#  'NLD': 'Netherlands',
#  'NOR': 'Norway',
#  'NPL': 'Nepal',
#  'NRU': 'Nauru',
#  'NZL': 'New Zealand',
#  'OMN': 'Oman',
#  'PAK': 'Pakistan',
#  'PAN': 'Panama',
#  'PER': 'Peru',
#  'PHL': 'Philippines',
#  'PLW': 'Palau',
#  'PNG': 'Papua New Guinea',
#  'POL': 'Poland',
#  'PRI': 'Puerto Rico',
#  'PRK': "Korea, Dem. People's Rep.",
#  'PRT': 'Portugal',
#  'PRY': 'Paraguay',
#  'PSE': 'West Bank and Gaza',
#  'PYF': 'French Polynesia',
#  'QAT': 'Qatar',
#  'ROU': 'Romania',
#  'RUS': 'Russian Federation',
#  'RWA': 'Rwanda',
#  'SAU': 'Saudi Arabia',
#  'SDN': 'Sudan',
#  'SEN': 'Senegal',
#  'SGP': 'Singapore',
#  'SLB': 'Solomon Islands',
#  'SLE': 'Sierra Leone',
#  'SLV': 'El Salvador',
#  'SMR': 'San Marino',
#  'SOM': 'Somalia',
#  'SRB': 'Serbia',
#  'SSD': 'South Sudan',
#  'STP': 'Sao Tome and Principe',
#  'SUR': 'Suriname',
#  'SVK': 'Slovak Republic',
#  'SVN': 'Slovenia',
#  'SWE': 'Sweden',
#  'SWZ': 'Eswatini',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'SYC': 'Seychelles',
#  'SYR': 'Syrian Arab Republic',
#  'TCA': 'Turks and Caicos Islands',
#  'TCD': 'Chad',
#  'TGO': 'Togo',
#  'THA': 'Thailand',
#  'TJK': 'Tajikistan',
#  'TKM': 'Turkmenistan',
#  'TLS': 'Timor-Leste',
#  'TON': 'Tonga',
#  'TTO': 'Trinidad and Tobago',
#  'TUN': 'Tunisia',
#  'TUR': 'Turkey',
#  'TUV': 'Tuvalu',
#  'TZA': 'Tanzania',
#  'UGA': 'Uganda',
#  'UKR': 'Ukraine',
#  'URY': 'Uruguay',
#  'USA': 'United States',
#  'UZB': 'Uzbekistan',
#  'VCT': 'St. Vincent and the Grenadines',
#  'VEN': 'Venezuela, RB',
#  'VGB': 'British Virgin Islands',
#  'VIR': 'Virgin Islands (U.S.)',
#  'VNM': 'Vietnam',
#  'VUT': 'Vanuatu',
#  'WSM': 'Samoa',
#  'XKX': 'Kosovo',
#  'YEM': 'Yemen, Rep.',
#  'ZAF': 'South Africa',
#  'ZMB': 'Zambia',
#  'ZWE': 'Zimbabwe'}

# %%
# Renaming countries in the WBI dataset to match the merged dataset names

wbi_clean = wbi_processed

wbi_clean.loc[wbi_clean.country == 'PRK', 'country code'] = 'KOR'    
wbi_clean.loc[wbi_clean.country == 'COG', 'country code'] = 'COD'    
wbi_clean.loc[wbi_clean.country == 'Congo, Dem. Rep.', 'country'] = 'Democratic Republic of the Congo'    
wbi_clean.loc[wbi_clean.country == 'Congo, Rep.', 'country'] = 'Democratic Republic of the Congo'
wbi_clean.loc[wbi_clean.country == 'Egypt, Arab Rep.', 'country'] = 'Egypt'
wbi_clean.loc[wbi_clean.country == 'Iran, Islamic Rep.', 'country'] = 'Iran'
wbi_clean.loc[wbi_clean.country == 'Kyrgyz Republic', 'country'] = 'Kyrgyzstan'
wbi_clean.loc[wbi_clean.country == 'Serbia', 'country'] = 'Republic of Serbia'
wbi_clean.loc[wbi_clean.country == 'Russian Federation', 'country'] = 'Russia'
wbi_clean.loc[wbi_clean.country == "Korea, Dem. People's Rep.", 'country'] = 'South Korea'
wbi_clean.loc[wbi_clean.country == 'Tanzania', 'country'] = 'United Republic of Tanzania'
wbi_clean.loc[wbi_clean.country == 'Venezuela, RB', 'country'] = 'Venezuela'
wbi_clean.loc[wbi_clean.country == 'United States', 'country'] = 'United States of America'

# %% [markdown]
# From that analysis, we see that data for `Taiwan` is missing in the `wbi_clean` dataset. So let's decide how to deal with it by looking into how many datapoints this corresponds to our dataset.

# %%
len(df_merged_emdat_usgs[df_merged_emdat_usgs['country code']== 'TWN'])
# Out:
# 0

# %% [markdown]
# As data for Taiwan corresponds to only 10 datapoints, we will remove those from this analysis. In the future, one can look into adding socioeconomic information about the country to the dataset.

# %%
df_merged_emdat_usgs = df_merged_emdat_usgs[df_merged_emdat_usgs['country code'] != 'TWN']

# %%
# Drop all countries not relevant from wbi dataset
countries_relevant =  list(df_merged_emdat_usgs['country'].unique())
wbi_clean = wbi_clean[wbi_clean['country'].isin(countries_relevant)]

# %%
# final merge 
df_merged_all= df_merged_emdat_usgs.merge(wbi_clean, how= 'inner', on=['country code', 'Year'])

df_merged_all.head()
# Out:
#    Year country code Continent  Total Affected        CPI        date  depth  \
# 0  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 1  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 2  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 3  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
# 4  1960          CHL  Americas       2003000.0  11.427251  1960-05-22   25.0
#
#    mag country_x    mmi  ... Rural population  \
# 0  9.5     Chile  8.842  ...          2615894
# 1  7.8     Chile  7.274  ...          2615894
# 2  6.8     Chile  6.925  ...          2615894
# 3  7.1     Chile  7.112  ...          2615894
# 4  5.8     Chile  5.841  ...          2615894
#
#   Rural population (% of total population) Urban population  \
# 0                                   32.164          5517094
# 1                                   32.164          5517094
# 2                                   32.164          5517094
# 3                                   32.164          5517094
# 4                                   32.164          5517094
#
#   Urban population (% of total population) Urban population growth (annual %)  \
# 0                                   67.836                                 ..
# 1                                   67.836                                 ..
# 2                                   67.836                                 ..
# 3                                   67.836                                 ..
# 4                                   67.836                                 ..
#
#   GDP (constant 2015 US$) GDP (current US$) GDP growth (annual %)  \
# 0        27084687058.6456        4110000000                    ..
# 1        27084687058.6456        4110000000                    ..
# 2        27084687058.6456        4110000000                    ..
# 3        27084687058.6456        4110000000                    ..
# 4        27084687058.6456        4110000000                    ..
#
#   GDP per capita (constant 2015 US$) country_y
# 0                   3330.22587253855     Chile
# 1                   3330.22587253855     Chile
# 2                   3330.22587253855     Chile
# 3                   3330.22587253855     Chile
# 4                   3330.22587253855     Chile
#
# [5 rows x 25 columns]

# %%
# Preparing model dataset
#df_merged_all.drop(columns=['country_x', 'country_x'])
df_merged_all =df_merged_all.drop(columns=['country_x'])
df_merged_all = df_merged_all.rename(columns={'country_y':'country'})

columns = list(df_merged_all.columns)
columns.remove('Total Affected')

df_merged_all = df_merged_all[columns + ['Total Affected']]

df_merged_model = df_merged_all.drop(columns=['Year','country code','Continent','date'])

# %%
df_merged_all.head()
# Out:
#    Year country code Continent        CPI        date  depth  mag    mmi  \
# 0  1960          CHL  Americas  11.427251  1960-05-22   25.0  9.5  8.842
# 1  1960          CHL  Americas  11.427251  1960-05-22   25.0  7.8  7.274
# 2  1960          CHL  Americas  11.427251  1960-05-22   25.0  6.8  6.925
# 3  1960          CHL  Americas  11.427251  1960-05-22   25.0  7.1  7.112
# 4  1960          CHL  Americas  11.427251  1960-05-22   25.0  5.8  5.841
#
#   Population density (people per sq. km of land area)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Population growth (annual %)  ... Rural population (% of total population)  \
# 0                           ..  ...                                   32.164
# 1                           ..  ...                                   32.164
# 2                           ..  ...                                   32.164
# 3                           ..  ...                                   32.164
# 4                           ..  ...                                   32.164
#
#   Urban population Urban population (% of total population)  \
# 0          5517094                                   67.836
# 1          5517094                                   67.836
# 2          5517094                                   67.836
# 3          5517094                                   67.836
# 4          5517094                                   67.836
#
#   Urban population growth (annual %) GDP (constant 2015 US$)  \
# 0                                 ..        27084687058.6456
# 1                                 ..        27084687058.6456
# 2                                 ..        27084687058.6456
# 3                                 ..        27084687058.6456
# 4                                 ..        27084687058.6456
#
#   GDP (current US$) GDP growth (annual %) GDP per capita (constant 2015 US$)  \
# 0        4110000000                    ..                   3330.22587253855
# 1        4110000000                    ..                   3330.22587253855
# 2        4110000000                    ..                   3330.22587253855
# 3        4110000000                    ..                   3330.22587253855
# 4        4110000000                    ..                   3330.22587253855
#
#   country Total Affected
# 0   Chile      2003000.0
# 1   Chile      2003000.0
# 2   Chile      2003000.0
# 3   Chile      2003000.0
# 4   Chile      2003000.0
#
# [5 rows x 24 columns]

# %%
df_merged_all['country'].unique()
# Out:
# array(['Chile', 'Albania', 'Colombia', 'Greece', 'France', 'Australia',
#        'Ethiopia', 'Indonesia', 'Costa Rica', 'Afghanistan', 'China',
#        'Ecuador', 'Guatemala', 'Argentina', 'Iran', 'Italy', 'Libya',
#        'Mexico', 'Turkey', 'United Republic of Tanzania', 'El Salvador',
#        'Nepal', 'New Zealand', 'Peru', 'United States of America',
#        'Nicaragua', 'Pakistan', 'Philippines', 'Iceland',
#        'Solomon Islands', 'Romania', 'Japan',
#        'Democratic Republic of the Congo', 'South Africa', 'Algeria',
#        'Belgium', 'Guinea', 'Bulgaria', 'Brazil', 'Bangladesh',
#        'Honduras', 'Papua New Guinea', 'India', 'Venezuela', 'Egypt',
#        'Malawi', 'Georgia', 'Myanmar', 'Kyrgyzstan', 'Sudan',
#        'Azerbaijan', 'Bolivia', 'Cyprus', 'Russia', 'Slovenia',
#        'Tajikistan', 'Dominican Republic', 'Panama', 'Morocco',
#        'Mozambique', 'Rwanda', 'Bhutan', 'Haiti', 'Spain',
#        'Republic of Serbia', 'Thailand', 'North Macedonia', 'Iraq'],
#       dtype=object)

# %%
df_merged_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1241 entries, 0 to 1240
# Data columns (total 20 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   CPI                                                     1241 non-null   float64
#  1   depth                                                   1241 non-null   float64
#  2   mag                                                     1241 non-null   float64
#  3   mmi                                                     845 non-null    float64
#  4   Population density (people per sq. km of land area)     1241 non-null   object
#  5   Population growth (annual %)                            1241 non-null   object
#  6   Population in largest city                              1241 non-null   object
#  7   Population in the largest city (% of urban population)  1241 non-null   object
#  8   Population, total                                       1241 non-null   object
#  9   Rural population                                        1241 non-null   object
#  10  Rural population (% of total population)                1241 non-null   object
#  11  Urban population                                        1241 non-null   object
#  12  Urban population (% of total population)                1241 non-null   object
#  13  Urban population growth (annual %)                      1241 non-null   object
#  14  GDP (constant 2015 US$)                                 1241 non-null   object
#  15  GDP (current US$)                                       1241 non-null   object
#  16  GDP growth (annual %)                                   1241 non-null   object
#  17  GDP per capita (constant 2015 US$)                      1241 non-null   object
#  18  country                                                 1241 non-null   object
#  19  Total Affected                                          1241 non-null   float64
# dtypes: float64(5), object(15)
# memory usage: 203.6+ KB

# %%
df_merged_all.to_csv(r'df_merged_all.csv')
df_merged_model.to_csv(r'df_merged_model.csv')

# %%
import pandas_profiling
# Profiling Report

profile = pandas_profiling.ProfileReport(df_merged_all, minimal = True)
profile.to_file(output_file="profiling-min-earthquakes.html")
# Out:
# Summarize dataset:   0%|          | 0/32 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
